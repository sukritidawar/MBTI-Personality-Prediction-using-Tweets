# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
pip install config
# Out:
# Collecting config
#   Downloading config-0.5.1-py2.py3-none-any.whl (20 kB)
# Installing collected packages: config
# Successfully installed config-0.5.1

# %%
import pandas as pd
import numpy as np

# %%
from tweepy import OAuthHandler
from tweepy import API
import config
import tweepy

# %% [markdown]
# ## For Ursula von der Leyen

# %%
#Add the user Id you want to get tweets
user_id_1="vonderleyen"
#Add the number of tweets you want to get
number_of_tweets=50

# %%
# Authorize our Twitter credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
tweets = api.user_timeline(screen_name=user_id_1, 
                           # 200 is the maximum allowed count
                           count=50,
                           lang = 'en',
                           include_rts = False,
                           # Necessary to keep full_text 
                           # otherwise only the first 140 words are extracted
                           tweet_mode = 'extended'
                           )

# %%
#transform the tweepy tweets into a 2D array that will populate the csv	
from pandas import DataFrame
outtweets = [[tweet.id_str, 
              tweet.created_at, 
              tweet.favorite_count, 
              tweet.retweet_count, 
              tweet.full_text.encode("utf-8").decode("utf-8")] 
             for idx,tweet in enumerate(tweets)]
df1 = DataFrame(outtweets,columns=["id","created_at","favorite_count","retweet_count", "text"])
df1.to_csv('%s_tweets.csv' % user_id_1,index=False)
df1
# Out:
#                      id  ...                                               text
# 0   1467901048400449542  ...  Die EU ist der 🌍 größte Spender von #COVID19-I...
# 1   1467872684038320128  ...  L'UE est le plus important donateur de vaccins...
# 2   1467870779799142400  ...  The EU is the biggest donor of #COVID19 vaccin...
# 3   1467830721842667527  ...  Ich gratuliere @karlnehammer zur heutigen Ange...
# 4   1466832740628770829  ...  Nachhaltiges Wirtschaften und ein bewusster Um...
# 5   1466815372577980416  ...  ¡Buenas noticias para España 🇪🇸!\n\nEspaña ha ...
# 6   1466793509420158977  ...  Our G7 leaders’ commitment echoes the 🇪🇺 #Glob...
# 7   1466725466249863172  ...  Deeply saddened by the passing of Mgr Aldo Gio...
# 8   1466722740258418693  ...  🇪🇪 Delighted to meet @AlarKaris and to congrat...
# 9   1466490030814281731  ...  Chanukkah is about hope - a flicker of light.\...
# 10  1466451090631708672  ...  Our #GlobalGateway strategy will meet the need...
# 11  1466440193049776132  ...  The EU stands with Latin America and the Carib...
# 12  1466390581144342533  ...  Vești bune pentru România: prima tranșă din fo...
# 13  1466390442661011462  ...  Good news for Romania with the 1st disbursemen...
# 14  1466363814023208960  ...  Le couple 🇫🇷🇩🇪 qu’il forma avec Helmut Schmidt...
# 15  1466362118760976392  ...  Président moderne, son mandat a changé la vie ...
# 16  1466360874193633280  ...  Toute sa vie, Valéry Giscard d’Estaing fit ava...
# 17  1466068813296939010  ...  Good calls with @UN’s @FilippoGrandi and @IOMc...
# 18  1466048087974100997  ...  About 1 billion doses have been delivered in t...
# 19  1466038965027446795  ...  To succeed, #GlobalGateway must be a #TeamEuro...
# 20  1466008795931418626  ...  We are now facing a double challenge in the fi...
# 21  1466003675625758721  ...  #GlobalGateway will support the green and digi...
# 22  1466002510049685509  ...  Many countries need a trusted partner to desig...
# 23  1466001177720627205  ...  For two years, the @EU_Commission focused on t...
# 24  1465991920904286210  ...  Today I will present Europe’s new connectivity...
# 25  1465744105657483266  ...  I just talked to Prime Minister of Iraq @MAKad...
# 26  1465699417231560715  ...  Glad to meet the Prime Ministers of Georgia 🇬🇪...
# 27  1465613119246503937  ...  Today's meeting of Commissioners on the pandem...
# 28  1465387208802766854  ...  Guter Austausch @a_schallenberg zur COVID-Lage...
# 29  1465374110159097860  ...  🇫🇷🇪🇺 Ravie de rencontrer le Président du Sénat...
# 30  1465295052687745026  ...  Renewable hydrogen will be key to the climate-...
# 31  1465257050234048512  ...  The EU &amp; its Member States will work hard ...
# 32  1465255576628342787  ...  Let's be better prepared against future pandem...
# 33  1465226244295962629  ...  We take the #Omicron variant very seriously. W...
# 34  1465218734180732928  ...  Let's take the EU-@NATO cooperation to the nex...
# 35  1464993276730163204  ...  Delighted to visit @STRATCOMCOE \n \nThe exper...
# 36  1464980104296153091  ...  To act in a timely, effective manner, proper i...
# 37  1464979190713929736  ...  🇱🇻 When one of our Member States is attacked, ...
# 38  1464912484507299842  ...  We have long been working together.\n\nWe are ...
# 39  1464908957533810688  ...  Lukashenko has failed in his bid to undermine ...
# 40  1464908313024503813  ...  Lithuania has been responding to this attack h...
# 41  1464892543372509184  ...  Good to be in Vilnius 🇱🇹 today with @NATO SG @...
# 42  1464646688426147847  ...  After we triggered emergency brake to tackle #...
# 43  1464324445431078922  ...  Very fruitful discussions this evening with @s...
# 44  1464238709612716032  ...  The European Union's contracts with manufactur...
# 45  1464236651077640197  ...  The news about the new COVID variant is very c...
# 46  1464200280451473414  ...  Asia matters to Europe.\n \nAs continents of i...
# 47  1464132568333398018  ...  The @EU_Commission will propose, in close coor...
# 48  1463915000314187778  ...  Felicitări @NicolaeCiuca pentru investirea în ...
# 49  1463851318695628804  ...  Impfen rettet Leben. \n\nDie neue COVID-Welle ...
#
# [50 rows x 5 columns]

# %% [markdown]
# ## For Nancy Pelosi

# %%
#Add the user Id you want to get tweets
user_id_2="SpeakerPelosi"
#Add the number of tweets you want to get
number_of_tweets=51

# %%
# Authorize our Twitter credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
tweets = api.user_timeline(screen_name=user_id_2, 
                           # 200 is the maximum allowed count
                           count=number_of_tweets,
                           lang = 'en',
                           include_rts = False,
                           # Necessary to keep full_text 
                           # otherwise only the first 140 words are extracted
                           tweet_mode = 'extended'
                           )

# %%
#transform the tweepy tweets into a 2D array that will populate the csv	
from pandas import DataFrame
outtweets = [[tweet.id_str, 
              tweet.created_at, 
              tweet.favorite_count, 
              tweet.retweet_count, 
              tweet.full_text.encode("utf-8").decode("utf-8")] 
             for idx,tweet in enumerate(tweets)]
df2 = DataFrame(outtweets,columns=["id","created_at","favorite_count","retweet_count", "text"])
df2.to_csv('%s_tweets.csv' % user_id_2,index=False)
df2
# Out:
#                      id  ...                                               text
# 0   1467953864867467268  ...  Senator Bob Dole was an extraordinary patriot....
# 1   1467945515904086016  ...  The Congress has and will continue our long bi...
# 2   1467945514809372681  ...  Allowing a country notorious for its appalling...
# 3   1467945513626578947  ...  While we must support and celebrate our athlet...
# 4   1467945512326373379  ...  As I noted when I called for a diplomatic boyc...
# 5   1467945510464012290  ...  I applaud President Biden’s strong leadership ...
# 6   1467862126979133452  ...  Instead of just talking about infrastructure, ...
# 7   1467693119114207240  ...  See what happened behind-the-scenes last week ...
# 8   1467629970155524105  ...  The #BuildBackBetter Act delivers on @HouseDem...
# 9   1467611241417949191  ...  As we honor his life, let us resolve to live u...
# 10  1467611240428101634  ...  Senator Dole championed our men and women in u...
# 11  1467611239304114176  ...  With great valor &amp; heroism, Senator Dole p...
# 12  1467611238037295107  ...  Today, our nation mourns the loss of a towerin...
# 13  1467202895892430858  ...  Decades of underinvestment in supply chain inf...
# 14  1466875317151223814  ...  .@HouseDemocrats have taken action to combat t...
# 15  1466854361687015435  ...  Congressional Democrats and President Biden wi...
# 16  1466854360416231436  ...  Democrats are using every tool at our disposal...
# 17  1466854349259382784  ...  The November jobs report is further evidence t...
# 18  1466827894454472707  ...  Democrats will continue to work to craft and p...
# 19  1466827882521677832  ...  Today, I am proud to sign the Continuing Resol...
# 20  1466788786793287688  ...  Join Members of Congress and me live at the Un...
# 21  1466505834968592399  ...  Just as the federal government invested in pro...
# 22  1466437320798883842  ...  Join me live at the U.S. Capitol for my weekly...
# 23  1466203482176774148  ...  Our Bipartisan Infrastructure package puts Ame...
# 24  1466188970501582867  ...  For six decades, the #PeoplesTree has brought ...
# 25  1466188959193735174  ...  As House Speaker, it was an honor to welcome A...
# 26  1466165827955310600  ...  Join members of the California Congressional d...
# 27  1466082350534733826  ...  Read my full statement on the Supreme Court or...
# 28  1466082349309956096  ...  The constitutional right to an abortion has be...
# 29  1466082347858546691  ...  Mississippi’s radical abortion ban, part of a ...
# 30  1466082345488986117  ...  The House is committed to defending women’s he...
# 31  1466082343748358146  ...  As the Supreme Court hears arguments in the ca...
# 32  1466041364651589635  ...  On World AIDS Day, and every day, let us summo...
# 33  1466041363489767436  ...  This year, our nation marked a solemn mileston...
# 34  1466041361786884099  ...  Every #WorldAIDSDay, the world comes together ...
# 35  1465310340804186121  ...  May it be a comfort to Congresswoman Meek’s ch...
# 36  1465310339751419915  ...  It was a great honor to know, serve with and s...
# 37  1465310337591296007  ...  Today, with great sadness over her passing, th...
# 38  1465075315135422464  ...  From my family to yours, we wish you and your ...
# 39  1463976110467780613  ...  In a spirit of gratitude, let us thank God for...
# 40  1463976107477291016  ...  Thanksgiving is an all-American holiday, when ...
# 41  1463698320740818947  ...  So sorry to hear of your loss, @SenSchumer. Yo...
# 42  1463574840112201739  ...  Thanks to @POTUS and @HouseDemocrats, jobless ...
# 43  1463536808663433225  ...  In previous years, pre-pandemic, my family and...
# 44  1463536807388274690  ...  Each Thanksgiving, and indeed every day, @stan...
# 45  1463334742003179522  ...  The bipartisan Infrastructure Investment and J...
# 46  1463334733392326656  ...  Today, I joined @RepAnnaEshoo, @RepBarbaraLee,...
# 47  1463253895065616389  ...  Join @RepAnnaEshoo, @RepBarbaraLee, @RepSpeier...
# 48  1462156053643239425  ...  Happy birthday, @POTUS! Your leadership contin...
# 49  1462140173815361542  ...  Let us renew our vow to honor the beautiful so...
#
# [50 rows x 5 columns]

# %% [markdown]
# ## For Jacinda Ardern

# %%
#Add the user Id you want to get tweets
user_id_3="jacindaardern"
#Add the number of tweets you want to get
number_of_tweets=52

# %%
# Authorize our Twitter credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
tweets = api.user_timeline(screen_name=user_id_3, 
                           # 200 is the maximum allowed count
                           count=number_of_tweets,
                           lang = 'en',
                           include_rts = False,
                           # Necessary to keep full_text 
                           # otherwise only the first 140 words are extracted
                           tweet_mode = 'extended'
                           )

# %%
#transform the tweepy tweets into a 2D array that will populate the csv	
from pandas import DataFrame
outtweets = [[tweet.id_str, 
              tweet.created_at, 
              tweet.favorite_count, 
              tweet.retweet_count, 
              tweet.full_text.encode("utf-8").decode("utf-8")] 
             for idx,tweet in enumerate(tweets)]
df3 = DataFrame(outtweets,columns=["id","created_at","favorite_count","retweet_count", "text"])
df3.to_csv('%s_tweets.csv' % user_id_3,index=False)
df3
# Out:
#                      id  ...                                               text
# 0   1438053103098425345  ...  @Jasonwalls92 A bit tardy, but a shortlist of ...
# 1   1436879317305204739  ...  In case you missed the press conference today ...
# 2   1435845477493194754  ...  Additional Pfizer vaccines purchased from Spai...
# 3   1346985068087033858  ...  Democracy - the right of people to exercise a ...
# 4   1346985066350608384  ...  Like so many others, I’ve been watching what’s...
# 5   1325154006549721088  ...  Congratulations President-elect @JoeBiden &amp...
# 6   1315430035554066432  ...                @Jasonwalls92 Vote. #LetsKeepMoving
# 7   1271739122860691456  ...  @grantrobertson1 I think you’re forgetting who...
# 8   1129176898603323393  ...  On my way home to NZ and heard the news that f...
# 9   1106398034827440128  ...  The person who has committed this violent act ...
# 10  1106397870628847617  ...  What has happened in Christchurch is an extrao...
# 11  1057100751955222530  ...  To those who felt the quake - GNS have confirm...
# 12  1055884525492785152  ...  @RuthDavidsonMSP Congratulations! It’s a journ...
# 13  1051569120066469889  ...            I salute you, @Kereru4PM #BirdOfTheYear
# 14  1042219863878451200  ...  @rihanna @GCMandela100 @GPforEducation @MFATgo...
# 15  1033461650488098816  ...  This is huge! Congratulations Rose https://t.c...
# 16  1032067227212689408  ...  So saddened to hear of the passing of Greg Boy...
# 17  1032003267528544256  ...  Congratulations @JulieAnneGenter ! So pleased ...
# 18  1030772215703171072  ...  The world has lost a great humanitarian, leade...
# 19  1025673416525799424  ...  Huge congratulations to the @crusadersrugby ! ...
# 20  1025166969635463168  ...  @mountain_goats @SamSachdevaNZ Thank you so mu...
# 21  1013717763049734145  ...  There are some accomplishments that are diffic...
# 22  1010948484843753474  ...  @ArchieDaRival @whaeapower @nzdodo @LittleSpro...
# 23   983070966967226368  ...  @Damian_Barr I’m deeply concerned about the in...
# 24   971565196727611397  ...  My message for International Women's Day. http...
# 25   968380343895158784  ...  @ch_gruetze I am so glad it made it to her! Th...
# 26   968271797165502464  ...  @RebelWilson Thank you! And please have the be...
# 27   966940381471387648  ...  @nkean Struggled to make the logistics work th...
# 28   966532890187018240  ...  And another one! Well done @nicoporteous Our y...
# 29   966494540625408007  ...  Huge congratulations to Snowboarder Zoi Sadows...
# 30   965022094743420928  ...  My huge and warm congratulations to @JulieAnne...
# 31   963183837491601408  ...  Just heard the news that Bill English has deci...
# 32   959326979307724800  ...  @alicenaotearoa @melulater Ha! That must be Pr...
# 33   955137644912025600  ...          @JustJen64 @wadegr @RocketLab I hear you.
# 34   955012295167328256  ...  Huge congratulations to Peter &amp; all the te...
# 35   954242665981202432  ...  Aww. Thanks for the toast @colincitizen and @T...
# 36   954109869509914624  ...  We thought 2017 was a big year! This year we’l...
# 37   949761337818624002  ...  So sad to hear of the passing of Jim Anderton ...
# 38   945097418818777088  ...  Wishing everyone a peaceful and merry Christma...
# 39   943766188294782978  ...  My thoughts are with Australia and the people ...
# 40   943368125201780736  ...  Secret Santa round two!?! #nzsecretsanta https...
# 41   943256667017248768  ...  @BecksT84 I am so glad it made it! A very Merr...
# 42   943255947681472512  ...  @jmodoh @FirstCatofNZ @NZClarke This really is...
# 43   942979907839172608  ...  So although my #nzsecretsanta didn't quite get...
# 44   942468347785916416  ...  I understand I jumped off our interview too ea...
# 45   940859295020830721  ...  @Veronic67082698 @nzsecretsanta That is so kin...
# 46   940720883722629121  ...  Here we go, @nzsecretsanta is on the way! http...
# 47   934640077279412226  ...  A quick reminder! Tonight between 6-7pm Civil ...
# 48   932815335752790016  ...  So you may have noticed I don't tweet especial...
# 49   911119989712683009  ...  Thanks so much for all your questions! Now go ...
#
# [50 rows x 5 columns]

# %% [markdown]
# ## For christine lagarde

# %%
#Add the user Id you want to get tweets
user_id_4="Lagarde"
#Add the number of tweets you want to get
number_of_tweets=69

# %%
# Authorize our Twitter credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
tweets = api.user_timeline(screen_name=user_id_4, 
                           # 200 is the maximum allowed count
                           count=number_of_tweets,
                           lang = 'en',
                           include_rts = False,
                           # Necessary to keep full_text 
                           # otherwise only the first 140 words are extracted
                           tweet_mode = 'extended'
                           )

# %%
#transform the tweepy tweets into a 2D array that will populate the csv	
from pandas import DataFrame
outtweets = [[tweet.id_str, 
              tweet.created_at, 
              tweet.favorite_count, 
              tweet.retweet_count, 
              tweet.full_text.encode("utf-8").decode("utf-8")] 
             for idx,tweet in enumerate(tweets)]
df4 = DataFrame(outtweets,columns=["id","created_at","favorite_count","retweet_count", "text"])
df4.to_csv('%s_tweets.csv' % user_id_4,index=False)
df4
# Out:
#                      id  ...                                               text
# 0   1467926876400369672  ...  At today’s #Eurogroup meeting we discussed the...
# 1   1467837507060572167  ...  Very interesting meeting with Belgian Prime Mi...
# 2   1467779962279186434  ...  For almost 20 years now, euro banknotes have b...
# 3   1467423359940050945  ...  Ngozi Okonjo-Iweala, Director-General of the @...
# 4   1467085087531544582  ...  Come ho detto la scorsa settimana da @fabfazio...
# 5   1466819200194916361  ...  Congratulations @gitagopinath on your new role...
# 6   1466810067416715266  ...  Merci beaucoup, Alice, for your virtual visit ...
# 7   1466771935568797826  ...  I am very happy to see that Europeans continue...
# 8   1466767426075328518  ...  In my interview with @aagalloni of Reuters, I ...
# 9   1466764478108872709  ...  Inflation is a concern for many euro area citi...
# 10  1466686551786770433  ...  Watch live: my conversation with @aagalloni on...
# 11  1466433309307715602  ...  I'll be speaking with @aagalloni about Europe’...
# 12  1466379496601313282  ...  Congratulations to my colleague @KlaasKnot for...
# 13  1466112761331605507  ...  During my visit to Italy, I met students from ...
# 14  1465386950400135173  ...  The task of separating truth from falsehood is...
# 15  1465357692583690246  ...  I’ll be speaking about the importance of scien...
# 16  1465063832653647875  ...  Grazie mille @fabfazio per l’ospitalità e l’in...
# 17  1465002580031987718  ...  Stasera sarò ospite di @fabfazio a @chetempoch...
# 18  1464520908199141381  ...  We do not expect the current rise in inflation...
# 19  1463964407751397380  ...  Nearly 1 in 3 women have experienced physical ...
# 20  1463813960029908992  ...  I’m looking forward to speaking to @fabfazio o...
# 21  1463526066832691206  ...  My warm congratulations to Magdalena Andersson...
# 22  1462802929543434240  ...  Congratulations to my colleague Jerome Powell ...
# 23  1462351064183750658  ...  During the pandemic, banks were not part of th...
# 24  1461746903079600134  ...  Very good to catch up with Commissioner Margre...
# 25  1461616514994475011  ...  Recent price rises are unwelcome and painful. ...
# 26  1461014581229363203  ...  Good discussion today with French Prime Minist...
# 27  1460904343457222656  ...  Women remain underrepresented in fundamental r...
# 28  1460632713237573632  ...  Regardez en direct : À 17:00 CET, je parle ave...
# 29  1457794749671239682  ...  I also met shortly with Austrian finance minis...
# 30  1457794745942482947  ...  At today’s Eurogroup meeting we discussed the ...
# 31  1457699320380248067  ...  Interesting Macroeconomic Dialogue meeting bef...
# 32  1456318350024486914  ...  Broadening women’s participation in economics ...
# 33  1456237389089812488  ...  I’m looking forward to opening our Women in Ec...
# 34  1456216342454054912  ...  We can only avoid catastrophic climate change ...
# 35  1456207256568094726  ...  As part of my visit to Lisbon, I spoke with Pe...
# 36  1455958201590030343  ...  It was an honour to speak with Portugal’s Coun...
# 37  1455952413085548556  ...  Parabéns @bancodeportugal on your 175th annive...
# 38  1455948869502750732  ...  Through its resolve, Europe has achieved a str...
# 39  1455824875118075904  ...  Our colleagues @bancodeportugal are celebratin...
# 40  1454765999677390848  ...  The #COP26 climate change talks are a crossroa...
# 41  1450778694889447424  ...  Ich habe Respekt vor Jens Weidmanns Entscheidu...
# 42  1450764656595845121  ...  I respect Jens Weidmann’s decision to step dow...
# 43  1449429640997650442  ...  Europe reaped the gains of globalisation in th...
# 44  1449023712079065096  ...  I’m honoured to be delivering this year’s Per ...
# 45  1448657348197642240  ...  On the margins of the IMF Annual Meeting in Wa...
# 46  1448635712962695168  ...  Great to meet Janet @SecYellen during the #IMF...
# 47  1448590262561906690  ...  Economic activity has been recovering, but the...
# 48  1448573866968748033  ...  Excellent as well to see progress being made o...
# 49  1448573863240114202  ...  Productive discussions at the G20 and G7 meeti...
#
# [50 rows x 5 columns]

# %%
# data = np.array([['Jacinda Ardern', text_data1], ['Justin Trudeau', text_data2], ['Theresa May', text_data3], ['Hillary Clinton', text_data4], ['Julia Gillard', text_data5]])
# df = pd.DataFrame(data)
# df.rename(columns = {0: 'User', 1: 'posts'}, inplace = True)
# df
# Out:
#               User                                              posts
# 0   Jacinda Ardern  @Jasonwalls92 A bit tardy, but a shortlist of ...
# 1   Justin Trudeau  Congratulations, Antonine - this recognition i...
# 2      Theresa May  At the Cenotaph this morning, we paid tribute ...
# 3  Hillary Clinton  Happy Thanksgiving! This one is all the more j...
# 4    Julia Gillard  Australians may be experiencing mixed emotions...
